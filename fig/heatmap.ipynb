# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

data = np.array([
    [2.8734, 0.4798, 8.6596, 6.309, 1.1068],
    [-2.4047, 2.2115, 6.1958, 3.0707, 0.0153],
    [-0.0928, 1.3314, 9.672, 4.2436, 1.8252],
    [-0.7551, 0.8163, 7.8495, 8.9375, 0.1101],
    [-0.2964, 1.3942, 8.8943, 3.7196, 4.0868]
])


# 您提供的数据矩阵
# data = np.array([
#     [29.3661, 21.1311, 25.4228, 20.513, 14.1707],
#     [10.5075, 26.2072, 19.9984, 17.2344, 11.0677],
#     [26.0436, 22.2543, 35.2374, 21.6419, 8.7067],
#     [25.9017, 20.4085, 32.2512, 24.3918, 15.3328],
#     [21.9465, -1.3992, 0, -1.8424, 17.974]
# ])

# 自定义X轴和Y轴刻度
x_labels = ['ar-en', 'de-en', 'fr-en', 'it-en', 'zh-en']
y_labels = ['ar-en', 'de-en', 'fr-en', 'it-en', 'zh-en']

# 使用Seaborn绘制热图
sns.heatmap(data, cmap='coolwarm', annot=True, fmt='.2f', xticklabels=x_labels, yticklabels=y_labels)

plt.xlabel('evaluate language direction')
plt.ylabel('finetune language direction')

# 显示图形
plt.savefig('heatmap.pdf', format='pdf', dpi=300)
plt.show()
